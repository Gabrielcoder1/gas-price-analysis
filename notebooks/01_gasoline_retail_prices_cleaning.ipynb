# %% [markdown]
# # Gas Price Analysis
#
# ## Project Overview
#
# This project will analyze gas price data and related fuel market data to better understand price trends over time.
#
# I will start by working with one dataset at a time. For each dataset, I will clean it, organize it, and try to understand what information it contains before combining it with other datasets.
#
# ## Current Datasets
#
# The project currently includes:
#
# - Gasoline retail prices
# - Transportation fuel spot prices
# - Weekly gasoline product supplied
# - Transportation economic trends data
#
# Some datasets may be used more than others depending on what is useful for the analysis.
#
# ## Basic Plan
#
# 1. Set up the project structure
# 2. Add and inspect one dataset
# 3. Clean and organize that dataset
# 4. Explore what the dataset shows
# 5. Repeat the process with the next dataset
# 6. Combine datasets when they are ready
# 7. Add extra data only if it helps answer the project questions
# 8. Create visuals and write findings

# %% [markdown]
# ## Step 1: Import Libraries and Tools
#
# In this step, I will import the Python libraries needed for loading, cleaning, and exploring the data.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
